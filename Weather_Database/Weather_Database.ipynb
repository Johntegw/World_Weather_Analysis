# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats=np.random.uniform(low=-90.000, high=90.000,size=1500)
lngs=np.random.uniform(low=-180.000, high=180.000,size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
            cities.append(city)
 # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1f35402005a85bbf80e889adf6f41c46

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_description = city_weather["weather"][0]["description"] 
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | huarmey
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | arman
# Processing Record 7 of Set 1 | bronnoysund
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | marzuq
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | gubkinskiy
# Processing Record 14 of Set 1 | tucumcari
# Processing Record 15 of Set 1 | odweyne
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | pimenta bueno
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | akyab
# Processing Record 20 of Set 1 | nizhnyaya omka
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | dryden
# Processing Record 23 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 1 | rimavska sobota
# Processing Record 25 of Set 1 | kahului
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | egvekinot
# Processing Record 28 of Set 1 | halkirk
# Processing Record 29 of Set 1 | solnechnyy
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | telde
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | maues
# Processing Record 42 of Set 1 | xining
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | necochea
# Processing Record 45 of Set 1 | margate
# Processing Record 46 of Set 1 | nome
# Processing Record 47 of Set 1 | poum
# Processing Record 48 of Set 1 | chippewa falls
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 2 | jackson
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | maputo
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | rosarito
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | shimoda
# Processing Record 11 of Set 2 | la ligua
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | derbent
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | vurnary
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | saint-augustin
# Processing Record 18 of Set 2 | angoram
# Processing Record 19 of Set 2 | dobson
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | carauari
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | whitehorse
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | adrar
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | inzer
# Processing Record 34 of Set 2 | mabaruma
# Processing Record 35 of Set 2 | umea
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | huilong
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | yumen
# Processing Record 43 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 2 | nueva gerona
# Processing Record 45 of Set 2 | yar-sale
# Processing Record 46 of Set 2 | qandala
# Processing Record 47 of Set 2 | oil city
# Processing Record 48 of Set 2 | luxor
# Processing Record 49 of Set 2 | carutapera
# Processing Record 50 of Set 2 | marsh harbour
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | kutum
# Processing Record 4 of Set 3 | anloga
# Processing Record 5 of Set 3 | najran
# Processing Record 6 of Set 3 | pacific grove
# Processing Record 7 of Set 3 | beruwala
# Processing Record 8 of Set 3 | carbonia
# Processing Record 9 of Set 3 | vryburg
# Processing Record 10 of Set 3 | constanta
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | gryazi
# Processing Record 14 of Set 3 | riyadh
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 3 | iskateley
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | luderitz
# Processing Record 24 of Set 3 | pangody
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | buin
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | brae
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | gat
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | hua hin
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | biak
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | vao
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | bara
# Processing Record 42 of Set 3 | pointe michel
# Processing Record 43 of Set 3 | tilichiki
# Processing Record 44 of Set 3 | wanning
# Processing Record 45 of Set 3 | zhangye
# Processing Record 46 of Set 3 | shingu
# Processing Record 47 of Set 3 | quilmana
# Processing Record 48 of Set 3 | ekhabi
# Processing Record 49 of Set 3 | rocha
# Processing Record 50 of Set 3 | sidi ali
# Processing Record 1 of Set 4 | ewa beach
# Processing Record 2 of Set 4 | vanimo
# Processing Record 3 of Set 4 | dudinka
# Processing Record 4 of Set 4 | altar
# Processing Record 5 of Set 4 | kurilsk
# Processing Record 6 of Set 4 | cap malheureux
# Processing Record 7 of Set 4 | monte cristi
# City not found. Skipping...
# Processing Record 8 of Set 4 | quatre cocos
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | mizan teferi
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | praia da vitoria
# Processing Record 14 of Set 4 | igrim
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | ust-kuyga
# Processing Record 17 of Set 4 | berlevag
# Processing Record 18 of Set 4 | damaturu
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | vaini
# Processing Record 21 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 4 | coolum beach
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | itarema
# Processing Record 25 of Set 4 | yefimovskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | laguna
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | sosnytsya
# Processing Record 29 of Set 4 | irricana
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | ca mau
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | kudahuvadhoo
# Processing Record 36 of Set 4 | eureka
# Processing Record 37 of Set 4 | athmallik
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | acarau
# Processing Record 41 of Set 4 | comodoro rivadavia
# Processing Record 42 of Set 4 | ciudad bolivar
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | lasa
# Processing Record 45 of Set 4 | speightstown
# Processing Record 46 of Set 4 | beringovskiy
# Processing Record 47 of Set 4 | nikolskoye
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | honiara
# Processing Record 50 of Set 4 | kangaatsiaq
# Processing Record 1 of Set 5 | ucluelet
# Processing Record 2 of Set 5 | sao jose da coroa grande
# Processing Record 3 of Set 5 | pirgos
# Processing Record 4 of Set 5 | aguada de pasajeros
# Processing Record 5 of Set 5 | merauke
# Processing Record 6 of Set 5 | araguatins
# City not found. Skipping...
# Processing Record 7 of Set 5 | aguas vermelhas
# Processing Record 8 of Set 5 | iisalmi
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | kolvereid
# Processing Record 11 of Set 5 | trairi
# Processing Record 12 of Set 5 | chantada
# Processing Record 13 of Set 5 | kencong
# Processing Record 14 of Set 5 | shirvan
# Processing Record 15 of Set 5 | matongo
# Processing Record 16 of Set 5 | fortuna
# Processing Record 17 of Set 5 | jacareacanga
# Processing Record 18 of Set 5 | ahipara
# Processing Record 19 of Set 5 | vostok
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | monroe
# Processing Record 22 of Set 5 | aklavik
# Processing Record 23 of Set 5 | oranjemund
# Processing Record 24 of Set 5 | mangochi
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | suchedniow
# Processing Record 27 of Set 5 | sabancuy
# Processing Record 28 of Set 5 | kloulklubed
# Processing Record 29 of Set 5 | levokumskoye
# Processing Record 30 of Set 5 | nalhati
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | brattleboro
# Processing Record 33 of Set 5 | mwinilunga
# Processing Record 34 of Set 5 | arlit
# Processing Record 35 of Set 5 | east wenatchee bench
# Processing Record 36 of Set 5 | demyansk
# Processing Record 37 of Set 5 | arica
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | kruisfontein
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 5 | calama
# Processing Record 43 of Set 5 | black river
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | seoul
# Processing Record 46 of Set 5 | fillan
# Processing Record 47 of Set 5 | bowen
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 50 of Set 5 | kuytun
# Processing Record 1 of Set 6 | awbari
# Processing Record 2 of Set 6 | nata
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | namibe
# Processing Record 5 of Set 6 | kapuskasing
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | liverpool
# Processing Record 9 of Set 6 | kaitangata
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | pingliang
# Processing Record 12 of Set 6 | onokhoy
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | nalut
# Processing Record 15 of Set 6 | avarua
# Processing Record 16 of Set 6 | road town
# Processing Record 17 of Set 6 | bunia
# Processing Record 18 of Set 6 | dikson
# Processing Record 19 of Set 6 | alpena
# Processing Record 20 of Set 6 | north bend
# Processing Record 21 of Set 6 | charters towers
# Processing Record 22 of Set 6 | okaihau
# Processing Record 23 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 24 of Set 6 | mackay
# Processing Record 25 of Set 6 | tete
# Processing Record 26 of Set 6 | taoudenni
# Processing Record 27 of Set 6 | opuwo
# Processing Record 28 of Set 6 | barbacoas
# Processing Record 29 of Set 6 | northam
# Processing Record 30 of Set 6 | guajara
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | georgetown
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | chapais
# Processing Record 35 of Set 6 | gunjur
# Processing Record 36 of Set 6 | aden
# Processing Record 37 of Set 6 | lavrentiya
# Processing Record 38 of Set 6 | bundaberg
# Processing Record 39 of Set 6 | agadez
# Processing Record 40 of Set 6 | le port
# Processing Record 41 of Set 6 | puerto escondido
# Processing Record 42 of Set 6 | moreira sales
# Processing Record 43 of Set 6 | cherskiy
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | carndonagh
# Processing Record 47 of Set 6 | nazarovo
# Processing Record 48 of Set 6 | ambon
# Processing Record 49 of Set 6 | ust-tsilma
# Processing Record 50 of Set 6 | anton lizardo
# Processing Record 1 of Set 7 | atbasar
# Processing Record 2 of Set 7 | axim
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 7 | rabo de peixe
# Processing Record 5 of Set 7 | waddan
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | palmer
# Processing Record 9 of Set 7 | tyret pervaya
# Processing Record 10 of Set 7 | altay
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | nabari
# Processing Record 13 of Set 7 | chicama
# Processing Record 14 of Set 7 | kathmandu
# Processing Record 15 of Set 7 | ingham
# Processing Record 16 of Set 7 | ried
# Processing Record 17 of Set 7 | pyapon
# Processing Record 18 of Set 7 | lubango
# Processing Record 19 of Set 7 | cam ranh
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 7 | leh
# Processing Record 24 of Set 7 | khor
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | chumikan
# Processing Record 27 of Set 7 | sola
# Processing Record 28 of Set 7 | morros
# Processing Record 29 of Set 7 | alliston
# Processing Record 30 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 7 | bilma
# Processing Record 32 of Set 7 | bambous virieux
# Processing Record 33 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 7 | leirvik
# Processing Record 35 of Set 7 | kozachi laheri
# Processing Record 36 of Set 7 | whakatane
# Processing Record 37 of Set 7 | stornoway
# Processing Record 38 of Set 7 | kingaroy
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | aksarka
# Processing Record 41 of Set 7 | amapa
# Processing Record 42 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 7 | diffa
# Processing Record 44 of Set 7 | kalaleh
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 7 | kirakira
# Processing Record 48 of Set 7 | san patricio
# Processing Record 49 of Set 7 | montlucon
# Processing Record 50 of Set 7 | panalingaan
# Processing Record 1 of Set 8 | goure
# Processing Record 2 of Set 8 | gornopravdinsk
# Processing Record 3 of Set 8 | freeport
# Processing Record 4 of Set 8 | provideniya
# Processing Record 5 of Set 8 | vila franca do campo
# Processing Record 6 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 8 | tezu
# Processing Record 8 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 8 | letterkenny
# Processing Record 10 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 8 | nchelenge
# Processing Record 12 of Set 8 | borgarnes
# Processing Record 13 of Set 8 | ponta do sol
# Processing Record 14 of Set 8 | muroto
# Processing Record 15 of Set 8 | krasnyy klyuch
# Processing Record 16 of Set 8 | faanui
# Processing Record 17 of Set 8 | progreso
# Processing Record 18 of Set 8 | gejiu
# Processing Record 19 of Set 8 | ekimchan
# Processing Record 20 of Set 8 | saint-georges
# Processing Record 21 of Set 8 | kita
# Processing Record 22 of Set 8 | durango
# Processing Record 23 of Set 8 | labuan
# Processing Record 24 of Set 8 | fukuma
# Processing Record 25 of Set 8 | coari
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | hohhot
# Processing Record 28 of Set 8 | marsa matruh
# Processing Record 29 of Set 8 | lorengau
# Processing Record 30 of Set 8 | karasjok
# Processing Record 31 of Set 8 | baiao
# Processing Record 32 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 8 | csurgo
# Processing Record 34 of Set 8 | ambatofinandrahana
# Processing Record 35 of Set 8 | sungaipenuh
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | princeton
# Processing Record 38 of Set 8 | muisne
# Processing Record 39 of Set 8 | krasnoselkup
# Processing Record 40 of Set 8 | rio grande
# Processing Record 41 of Set 8 | coahuayana
# Processing Record 42 of Set 8 | shache
# Processing Record 43 of Set 8 | kungur
# Processing Record 44 of Set 8 | salalah
# Processing Record 45 of Set 8 | salinas
# Processing Record 46 of Set 8 | asfi
# Processing Record 47 of Set 8 | penzance
# Processing Record 48 of Set 8 | constitucion
# Processing Record 49 of Set 8 | khilok
# Processing Record 50 of Set 8 | jalpan
# Processing Record 1 of Set 9 | hukuntsi
# Processing Record 2 of Set 9 | ossora
# Processing Record 3 of Set 9 | sanandaj
# Processing Record 4 of Set 9 | san juan
# Processing Record 5 of Set 9 | usinsk
# Processing Record 6 of Set 9 | udachnyy
# Processing Record 7 of Set 9 | bubaque
# Processing Record 8 of Set 9 | sur
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | raisinghnagar
# Processing Record 11 of Set 9 | torbay
# Processing Record 12 of Set 9 | havelock
# Processing Record 13 of Set 9 | plettenberg bay
# Processing Record 14 of Set 9 | nishihara
# Processing Record 15 of Set 9 | yueyang
# Processing Record 16 of Set 9 | ebano
# City not found. Skipping...
# Processing Record 17 of Set 9 | shkotovo
# Processing Record 18 of Set 9 | kewanee
# Processing Record 19 of Set 9 | touros
# Processing Record 20 of Set 9 | grande-synthe
# Processing Record 21 of Set 9 | mount gambier
# Processing Record 22 of Set 9 | columbus
# Processing Record 23 of Set 9 | abbeville
# Processing Record 24 of Set 9 | dezhou
# Processing Record 25 of Set 9 | darnah
# Processing Record 26 of Set 9 | port hawkesbury
# Processing Record 27 of Set 9 | birjand
# Processing Record 28 of Set 9 | anadyr
# Processing Record 29 of Set 9 | wladyslawowo
# Processing Record 30 of Set 9 | galesong
# Processing Record 31 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 32 of Set 9 | qui nhon
# Processing Record 33 of Set 9 | merrill
# Processing Record 34 of Set 9 | emmett
# Processing Record 35 of Set 9 | vuktyl
# Processing Record 36 of Set 9 | sambava
# Processing Record 37 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 9 | somerset west
# Processing Record 40 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 9 | rockport
# Processing Record 42 of Set 9 | christchurch
# Processing Record 43 of Set 9 | cabra
# Processing Record 44 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 9 | otavi
# Processing Record 46 of Set 9 | ferme-neuve
# Processing Record 47 of Set 9 | ngunguru
# Processing Record 48 of Set 9 | karatau
# Processing Record 49 of Set 9 | humberto de campos
# Processing Record 50 of Set 9 | rubiataba
# Processing Record 1 of Set 10 | whitianga
# Processing Record 2 of Set 10 | tiznit
# Processing Record 3 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 10 | aljezur
# Processing Record 5 of Set 10 | fort nelson
# Processing Record 6 of Set 10 | rorvik
# Processing Record 7 of Set 10 | bereda
# Processing Record 8 of Set 10 | presidencia roque saenz pena
# Processing Record 9 of Set 10 | nuuk
# Processing Record 10 of Set 10 | nokia
# Processing Record 11 of Set 10 | nianzishan
# Processing Record 12 of Set 10 | mersing
# Processing Record 13 of Set 10 | valparaiso
# Processing Record 14 of Set 10 | yulara
# Processing Record 15 of Set 10 | tabou
# Processing Record 16 of Set 10 | eyl
# Processing Record 17 of Set 10 | cobija
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | amlagora
# Processing Record 20 of Set 10 | abu dhabi
# Processing Record 21 of Set 10 | upernavik
# Processing Record 22 of Set 10 | prieska
# Processing Record 23 of Set 10 | makakilo city
# Processing Record 24 of Set 10 | innisfail
# Processing Record 25 of Set 10 | salo
# Processing Record 26 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 10 | saint anthony
# Processing Record 28 of Set 10 | steinbach
# Processing Record 29 of Set 10 | mizque
# Processing Record 30 of Set 10 | kharp
# Processing Record 31 of Set 10 | quesnel
# Processing Record 32 of Set 10 | zhezkazgan
# Processing Record 33 of Set 10 | alice springs
# Processing Record 34 of Set 10 | alofi
# Processing Record 35 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 10 | anamoros
# Processing Record 37 of Set 10 | tucuman
# Processing Record 38 of Set 10 | dingle
# Processing Record 39 of Set 10 | dire
# Processing Record 40 of Set 10 | minab
# Processing Record 41 of Set 10 | teahupoo
# Processing Record 42 of Set 10 | mayumba
# Processing Record 43 of Set 10 | padang
# Processing Record 44 of Set 10 | college
# Processing Record 45 of Set 10 | puri
# Processing Record 46 of Set 10 | rotifunk
# Processing Record 47 of Set 10 | fremont
# Processing Record 48 of Set 10 | walvis bay
# Processing Record 49 of Set 10 | yarada
# Processing Record 50 of Set 10 | puerto colombia
# Processing Record 1 of Set 11 | kiisa
# Processing Record 2 of Set 11 | aksu
# Processing Record 3 of Set 11 | porkhov
# Processing Record 4 of Set 11 | iqaluit
# Processing Record 5 of Set 11 | cintalapa
# Processing Record 6 of Set 11 | montepuez
# Processing Record 7 of Set 11 | diego de almagro
# Processing Record 8 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 11 | coquimbo
# Processing Record 10 of Set 11 | pishin
# Processing Record 11 of Set 11 | saquarema
# Processing Record 12 of Set 11 | bonnyville
# Processing Record 13 of Set 11 | monte escobedo
# Processing Record 14 of Set 11 | herat
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | portland
# Processing Record 17 of Set 11 | komsomolskiy
# Processing Record 18 of Set 11 | sinnamary
# Processing Record 19 of Set 11 | south venice
# Processing Record 20 of Set 11 | amahai
# Processing Record 21 of Set 11 | yuci
# Processing Record 22 of Set 11 | viksoyri
# City not found. Skipping...
# Processing Record 23 of Set 11 | nizhneangarsk
# Processing Record 24 of Set 11 | kotelnich
# Processing Record 25 of Set 11 | kawalu
# Processing Record 26 of Set 11 | broken hill
# Processing Record 27 of Set 11 | stokmarknes
# Processing Record 28 of Set 11 | sukumo
# Processing Record 29 of Set 11 | smidovich
# Processing Record 30 of Set 11 | luanda
# Processing Record 31 of Set 11 | destin
# Processing Record 32 of Set 11 | batouri
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | norcasia
# Processing Record 35 of Set 11 | santa cruz
# Processing Record 36 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 11 | inirida
# Processing Record 38 of Set 11 | paramonga
# Processing Record 39 of Set 11 | abha
# Processing Record 40 of Set 11 | port moresby
# Processing Record 41 of Set 11 | burica
# City not found. Skipping...
# Processing Record 42 of Set 11 | mahabad
# Processing Record 43 of Set 11 | thinadhoo
# Processing Record 44 of Set 11 | waipawa
# Processing Record 45 of Set 11 | arcata
# Processing Record 46 of Set 11 | olga
# Processing Record 47 of Set 11 | shiyan
# Processing Record 48 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 49 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | jiangyou
# Processing Record 1 of Set 12 | nichinan
# Processing Record 2 of Set 12 | erenhot
# Processing Record 3 of Set 12 | baft
# Processing Record 4 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 12 | kasongo-lunda
# Processing Record 6 of Set 12 | sorsk
# Processing Record 7 of Set 12 | denpasar
# Processing Record 8 of Set 12 | port hardy
# Processing Record 9 of Set 12 | verkhniy avzyan
# Processing Record 10 of Set 12 | muravlenko
# Processing Record 11 of Set 12 | dubti
# Processing Record 12 of Set 12 | voyvozh
# Processing Record 13 of Set 12 | sterling
# Processing Record 14 of Set 12 | chara
# Processing Record 15 of Set 12 | itaqui
# Processing Record 16 of Set 12 | iquitos
# Processing Record 17 of Set 12 | koslan
# Processing Record 18 of Set 12 | rafai
# Processing Record 19 of Set 12 | korla
# Processing Record 20 of Set 12 | tamandare
# Processing Record 21 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 12 | powell river
# Processing Record 23 of Set 12 | taltal
# Processing Record 24 of Set 12 | aasiaat
# Processing Record 25 of Set 12 | mareeba
# Processing Record 26 of Set 12 | keuruu
# Processing Record 27 of Set 12 | burgeo
# Processing Record 28 of Set 12 | guarapari
# Processing Record 29 of Set 12 | marawi
# Processing Record 30 of Set 12 | roela
# Processing Record 31 of Set 12 | riverton
# Processing Record 32 of Set 12 | airai
# Processing Record 33 of Set 12 | kandrian
# Processing Record 34 of Set 12 | kharan
# Processing Record 35 of Set 12 | yuksekova
# Processing Record 36 of Set 12 | ocampo
# Processing Record 37 of Set 12 | caravelas
# Processing Record 38 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 12 | leeston
# Processing Record 40 of Set 12 | sawakin
# Processing Record 41 of Set 12 | portales
# Processing Record 42 of Set 12 | bhainsa
# Processing Record 43 of Set 12 | miandrivazo
# Processing Record 44 of Set 12 | nadym
# Processing Record 45 of Set 12 | richards bay
# Processing Record 46 of Set 12 | coihaique
# Processing Record 47 of Set 12 | poienile de sub munte
# Processing Record 48 of Set 12 | jinchang
# Processing Record 49 of Set 12 | altagracia de orituco
# Processing Record 50 of Set 12 | tabat
# Processing Record 1 of Set 13 | grand gaube
# Processing Record 2 of Set 13 | gamba
# Processing Record 3 of Set 13 | nicoya
# Processing Record 4 of Set 13 | aleksandrov gay
# Processing Record 5 of Set 13 | guiratinga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 553

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     -9.38        77         100
# 1       Rikitea      PF -23.1203 -134.9692     76.80        64          80
# 2       Huarmey      PE -10.0681  -78.1522     78.91        76         100
# 3  Saint George      US  37.1041 -113.5841     42.26        52           0
# 4         Arman      RU  59.7000  150.1667     -1.28        99          72
# 5   Bronnoysund      NO  65.4625   12.1997     41.00        70         100
# 6        Hasaki      JP  35.7333  140.8333     63.21        91         100
# 7    Butaritari      KI   3.0707  172.7902     81.23        81         100
# 8        Marzuq      YE  14.4000   46.4667     78.28        44          94
# 9        Albany      US  42.6001  -73.9662     47.05        53          79
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        9.08       broken clouds
# 2        3.02     overcast clouds
# 3        0.00           clear sky
# 4        5.53       broken clouds
# 5       16.11     overcast clouds
# 6       34.25          light rain
# 7       17.18          light rain
# 8       12.66     overcast clouds
# 9        1.01       broken clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     -9.38        77         100
# 1       Rikitea      PF -23.1203 -134.9692     76.80        64          80
# 2       Huarmey      PE -10.0681  -78.1522     78.91        76         100
# 3  Saint George      US  37.1041 -113.5841     42.26        52           0
# 4         Arman      RU  59.7000  150.1667     -1.28        99          72
# 5   Bronnoysund      NO  65.4625   12.1997     41.00        70         100
# 6        Hasaki      JP  35.7333  140.8333     63.21        91         100
# 7    Butaritari      KI   3.0707  172.7902     81.23        81         100
# 8        Marzuq      YE  14.4000   46.4667     78.28        44          94
# 9        Albany      US  42.6001  -73.9662     47.05        53          79
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        9.08       broken clouds
# 2        3.02     overcast clouds
# 3        0.00           clear sky
# 4        5.53       broken clouds
# 5       16.11     overcast clouds
# 6       34.25          light rain
# 7       17.18          light rain
# 8       12.66     overcast clouds
# 9        1.01       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]



# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     -9.38        77         100
# 1       Rikitea      PF -23.1203 -134.9692     76.80        64          80
# 2       Huarmey      PE -10.0681  -78.1522     78.91        76         100
# 3  Saint George      US  37.1041 -113.5841     42.26        52           0
# 4         Arman      RU  59.7000  150.1667     -1.28        99          72
# 5   Bronnoysund      NO  65.4625   12.1997     41.00        70         100
# 6        Hasaki      JP  35.7333  140.8333     63.21        91         100
# 7    Butaritari      KI   3.0707  172.7902     81.23        81         100
# 8        Marzuq      YE  14.4000   46.4667     78.28        44          94
# 9        Albany      US  42.6001  -73.9662     47.05        53          79
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        9.08       broken clouds
# 2        3.02     overcast clouds
# 3        0.00           clear sky
# 4        5.53       broken clouds
# 5       16.11     overcast clouds
# 6       34.25          light rain
# 7       17.18          light rain
# 8       12.66     overcast clouds
# 9        1.01       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
